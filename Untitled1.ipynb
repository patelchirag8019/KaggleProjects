# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("D://CodingNest//Kaggle//Projects//RottenTomatos//Data//rotten_tomatoes_movies//rotten_tomatoes_movies.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16638 entries, 0 to 16637
# Data columns (total 23 columns):
# rotten_tomatoes_link             16638 non-null object
# movie_title                      16638 non-null object
# movie_info                       16614 non-null object
# critics_consensus                8309 non-null object
# poster_image_url                 16638 non-null object
# rating                           16638 non-null object
# genre                            16621 non-null object
# directors                        16524 non-null object
# writers                          15289 non-null object
# cast                             16354 non-null object
# in_theaters_date                 15823 non-null object
# on_streaming_date                16636 non-null object
# runtime_in_minutes               16483 non-null float64
# studio_name                      16222 non-null object
# tomatometer_status               16638 non-null object
# ...

# %%
df
# Out:
#                                    rotten_tomatoes_link  \
# 0                                            /m/0814255
# 1                                            /m/0878835
# 2                                                 /m/10
# 3                               /m/1000013-12_angry_men
# 4                /m/1000079-20000_leagues_under_the_sea
# 5                                           /m/10000_bc
# 6                                   /m/1000121-39_steps
# 7                                /m/1000123-310_to_yuma
# 8                                    /m/10002008-charly
# 9                            /m/1000204-abraham_lincoln
# 10                               /m/10002114-dark_water
# 11                                   /m/1000224-accused
# 12                                /m/10002516-lost_city
# 13                           /m/10002519-breaking_point
# 14                                 /m/1000253-adams_rib
# 15                   /m/10002635-bridge_of_san_luis_rey
# ...

# %%
df2 = df[['rotten_tomatoes_link', 'genre', 'rating']]

# %%
df2
# Out:
#                                    rotten_tomatoes_link  \
# 0                                            /m/0814255
# 1                                            /m/0878835
# 2                                                 /m/10
# 3                               /m/1000013-12_angry_men
# 4                /m/1000079-20000_leagues_under_the_sea
# 5                                           /m/10000_bc
# 6                                   /m/1000121-39_steps
# 7                                /m/1000123-310_to_yuma
# 8                                    /m/10002008-charly
# 9                            /m/1000204-abraham_lincoln
# 10                               /m/10002114-dark_water
# 11                                   /m/1000224-accused
# 12                                /m/10002516-lost_city
# 13                           /m/10002519-breaking_point
# 14                                 /m/1000253-adams_rib
# 15                   /m/10002635-bridge_of_san_luis_rey
# ...

# %%
df1 = pd.read_csv("D://CodingNest//Kaggle//Projects//RottenTomatos//Data//rotten_tomatoes_reviews//rotten_tomatoes_reviews.csv")

# %%
df1
# Out:
#        rotten_tomatoes_link review_date               critic_publication  \
# 0                /m/0814255  2015-01-09                  Cinemaphile.org
# 1                /m/0814255  2012-07-31                      7M Pictures
# 2                /m/0814255  2011-11-05       Star-Democrat (Easton, MD)
# 3                /m/0814255  2011-04-25                   ComingSoon.net
# 4                /m/0814255  2011-04-04                       Movies.com
# 5                /m/0814255  2010-08-04             Window to the Movies
# 6                /m/0814255  2010-07-17             Matt's Movie Reviews
# 7                /m/0814255  2010-07-06                   Boston Phoenix
# 8                /m/0814255  2010-07-06                  Groucho Reviews
# 9                /m/0814255  2010-07-06           JoBlo's Movie Emporium
# 10               /m/0814255  2010-07-04                     Cinema Sight
# 11               /m/0814255  2010-06-30                 Movie Metropolis
# ...
